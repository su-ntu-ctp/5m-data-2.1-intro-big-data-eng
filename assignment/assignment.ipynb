# %% [markdown]
# # Assignment

# %% [markdown]
# ## Setup Environment

# %%
# Copy and paste the connection code from step 3 above into this cell below the line
# ------------------------------------------------------------------------------

from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://set1sctpdsai_db_user:Y2F6TfIGTpllMRrq@cluster0.g3rtxjg.mongodb.net/?appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %% [markdown]
# ### Create secret file locally
#
# > Make sure your connection is good before running this cell

# %%
# Cell: Export MongoDB configuration to .env file
import os

# Create .env file with MongoDB configuration
env_content = f"""# MongoDB Configuration
# Auto-generated from notebook
MONGODB_URI='{uri}'
"""

with open('.env', 'w') as f:
    f.write(env_content)

print("✅ Configuration exported to .env file")
# Out:
# ✅ Configuration exported to .env file

# %%
import pymongo
client.list_database_names()
# Out:
# ['sample_mflix', 'admin', 'local']

# %%
db = client.sample_mflix
db.list_collection_names()
# Out:
# ['embedded_movies', 'movies', 'sessions', 'users', 'theaters', 'comments']

# %%
movies = db.movies

# %% [markdown]
# ## Brief
#
# Write the Python codes for the following questions.

# %% [markdown]
# ## Instructions
#
# Paste the answer as Python in the answer code section below each question.

# %% [markdown]
# ### Question 1
#
# Question: From the `movies` collection, return the documents with the `plot` that starts with `"war"` in acending order of released date, print only title, plot and released fields. Limit the result to 5.

# %% [markdown]
# Please do not change the function, just write your code inside the function:
#
# Your Answer:

# %%
def war_movies(movies_collection):
    """
    Enter Your Solution Here

    """
    results = []

    # Start your solutions
    for m in movies_collection.find({"plot": {"$regex": "^[Ww]ar"}}).sort('released', pymongo.ASCENDING).limit(5):
        results.append({
            'title': m['title'],
            'plot': m['plot'],
            'released': m['released']
        })
    # Your solution ends here
    
    return results

# %%
# You can test your function here by removing comment in the line below
# war_movies(movies)

# %% [markdown]
# #### RUN the following cell First

# %%
# Cell: Export solution for testing
import inspect

# Save the function to student_solution.py
with open('my_solution_q1.py', 'w') as f:
    f.write("import pymongo\n\n")
    f.write("# Student's solution\n")
    # Export with the name the test expects
    source = inspect.getsource(war_movies)
    # Replace function name to match what tests expect
    f.write(source)

print("✅ My Solution exported")
# Out:
# ✅ My Solution exported

# %% [markdown]
# #### Checking My Solution

# %%
# !pytest test_solution_q1.py -v
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.10.13, pytest-8.4.1, pluggy-1.5.0 -- /Users/mlnotes/miniconda3/envs/bde/bin/python
# cachedir: .pytest_cache
# rootdir: /Users/mlnotes/Documents/Git_Remote/5m-data-2.1-intro-big-data-eng/assignment
# plugins: anyio-4.7.0
# collected 8 items
#
# test_solution_q1.py::test_function_exists PASSED                         [ 12%]
# test_solution_q1.py::test_returns_list PASSED                            [ 25%]
# test_solution_q1.py::test_returns_5_or_fewer_results PASSED              [ 37%]
# test_solution_q1.py::test_correct_fields_returned PASSED                 [ 50%]
# test_solution_q1.py::test_plots_start_with_war PASSED                    [ 62%]
# test_solution_q1.py::test_sorted_by_released_ascending PASSED            [ 75%]
# test_solution_q1.py::test_no_non_war_plots PASSED                        [ 87%]
# ...

# %% [markdown]
# ### Question 2
#
# Question: Group by `rated` and count the number of movies in each.
#
# Please do not change the function, just write your code inside the function:
#
# Your Answer:

# %%
def group_by_rated(movies_collection):
    """
    Group by rated and count the number of movies in each.
    Returns a list of dictionaries with '_id' (rating) and 'movie_count'
    """
    results = []
    
    # Start your solution
    stage_group_rated = {
        "$group": {
            "_id": "$rated",
            "movie_count": {"$sum": 1},
        }
    }
    
    pipeline = [stage_group_rated]
    
    for result in movies_collection.aggregate(pipeline):
        results.append(result)
    # End your solution
    
    return results

# %%
# You can test your function here by removing comment in the line below
# group_by_rated(movies)

# %% [markdown]
# #### RUN the following cell First

# %%
# Export Q2 solution
import inspect

with open('my_solution_q2.py', 'w') as f:
    f.write("import pymongo\n\n")
    source = inspect.getsource(group_by_rated)
    f.write(source)

print("✅ Question 2 solution exported")
# Out:
# ✅ Question 2 solution exported

# %%
# !pytest test_solution_q2.py -v
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.10.13, pytest-8.4.1, pluggy-1.5.0 -- /Users/mlnotes/miniconda3/envs/bde/bin/python
# cachedir: .pytest_cache
# rootdir: /Users/mlnotes/Documents/Git_Remote/5m-data-2.1-intro-big-data-eng/assignment
# plugins: anyio-4.7.0
# collected 8 items
#
# test_solution_q2.py::test_function_exists PASSED                         [ 12%]
# test_solution_q2.py::test_returns_list PASSED                            [ 25%]
# test_solution_q2.py::test_returns_results PASSED                         [ 37%]
# test_solution_q2.py::test_result_structure PASSED                        [ 50%]
# test_solution_q2.py::test_counts_are_positive PASSED                     [ 62%]
# test_solution_q2.py::test_total_count_matches PASSED                     [ 75%]
# test_solution_q2.py::test_compare_with_correct_implementation PASSED     [ 87%]
# ...

# %% [markdown]
# Answer:
#
# ```python
#
# ```
#
# ### Question 3
#
# Question: Count the number of movies with 3 comments or more.
#
# Answer:
#
# ```python
#
# ```
#
# ## Submission
#
# - Submit the URL of the GitHub Repository that contains your work to NTU black board.
# - Should you reference the work of your classmate(s) or online resources, give them credit by adding either the name of your classmate or URL.

# %%
# Export Q3 solution
with open('my_solution_q3.py', 'w') as f:
    f.write("import pymongo\n\n")
    source = inspect.getsource(count_movies_with_comments)
    f.write(source)

print("✅ Question 3 solution exported")
